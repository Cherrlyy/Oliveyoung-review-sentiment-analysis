# %%
import pandas as pd

# %%
polarity = pd.read_csv('product_polarity.csv', encoding='UTF-8')
polarity
# Out:
#                 id                                               name  \
# 0    A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 1    A000000192752  [2023어워즈/4년연속] 라운드랩 1025 독도 토너 500ml 어워즈 한정기획(...
# 2    A000000155253  [2023어워즈] 아비브 어성초 카밍 토너 스킨부스터 더블 기획 (200ml+200ml)
# 3    A000000192545  브링그린 티트리시카  수딩 토너 500ml 어워즈 한정기획(+크림20ml+징크테카세...
# 4    A000000174370                              바이오더마 하이드라비오 토너 500ml
# ..             ...                                                ...
# 143  A000000141900   [1+1 모공케어] 유세린 더머토클린 클래리파잉 토너 더블기획 (200ml+200ml)
# 144  A000000163510                      비욘드 엔젤아쿠아 수분 진정 토너 500ml (비건)
# 145  A000000137657                               라네즈옴므 액티브워터 스킨 180ml
# 146  A000000166492                           수이스킨 어린새싹 클린 토너 더블 기획세트
# 147  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
#
#      soothing  moisturizing   skin
# 0       0.525         0.260  0.130
# 1       0.700         0.655  0.300
# ...

# %%
category = ['water', 'serum', 'cream', 'oil', 'balm']
water = '스킨|미스트|토너|토닉|스프레이'
serum = '에센스|세럼|앰플|로션'
cream = '크림'
oil = '오일'
balm = '밤|스틱'

# %%
for c in category:
    polarity.loc[polarity['name'].str.contains(eval(c)), 'name'] = c

# %%
polarity.groupby('name').count()
# Out:
#                                  id  soothing  moisturizing  skin
# name
# oil                               2         2             2     2
# serum                            14        14            14    14
# water                           126       126           126   126
# 디오디너리 글리코릭 애시드 7% 토닝 솔루션 240ml    1         1             1     1
# 라끄베르 옴므리차지 애프터쉐이브 185ml           1         1             1     1
# 바버501 애프터 쉐이브 165ml 2종 택1         1         1             1     1
# 원씽 나이아신아마이드 10%                   1         1             1     1
# 클럽맨리저브 위스키우즈 에프터쉐이브 177ml         1         1             1     1
# 클럽맨피노드 머스크 에프터쉐이브코롱 177ml         1         1             1     1

# %%
review = pd.read_csv('review_final_preprocessed.csv', encoding='UTF-8')
product = review.drop_duplicates(['name'])
product = product[['id', 'name']]
product
# Out:
#                   id                                               name
# 0      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 200    A000000192752  [2023어워즈/4년연속] 라운드랩 1025 독도 토너 500ml 어워즈 한정기획(...
# 400    A000000155253  [2023어워즈] 아비브 어성초 카밍 토너 스킨부스터 더블 기획 (200ml+200ml)
# 600    A000000192545  브링그린 티트리시카  수딩 토너 500ml 어워즈 한정기획(+크림20ml+징크테카세...
# 800    A000000174370                              바이오더마 하이드라비오 토너 500ml
# ...              ...                                                ...
# 31201  A000000141900   [1+1 모공케어] 유세린 더머토클린 클래리파잉 토너 더블기획 (200ml+200ml)
# 31401  A000000163510                      비욘드 엔젤아쿠아 수분 진정 토너 500ml (비건)
# 31801  A000000137657                               라네즈옴므 액티브워터 스킨 180ml
# 32001  A000000166492                           수이스킨 어린새싹 클린 토너 더블 기획세트
# 32201  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
#
# [148 rows x 2 columns]

# %%
for c in category:
    product[c] = 0
product
# Out:
#                   id                                               name  \
# 0      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 200    A000000192752  [2023어워즈/4년연속] 라운드랩 1025 독도 토너 500ml 어워즈 한정기획(...
# 400    A000000155253  [2023어워즈] 아비브 어성초 카밍 토너 스킨부스터 더블 기획 (200ml+200ml)
# 600    A000000192545  브링그린 티트리시카  수딩 토너 500ml 어워즈 한정기획(+크림20ml+징크테카세...
# 800    A000000174370                              바이오더마 하이드라비오 토너 500ml
# ...              ...                                                ...
# 31201  A000000141900   [1+1 모공케어] 유세린 더머토클린 클래리파잉 토너 더블기획 (200ml+200ml)
# 31401  A000000163510                      비욘드 엔젤아쿠아 수분 진정 토너 500ml (비건)
# 31801  A000000137657                               라네즈옴므 액티브워터 스킨 180ml
# 32001  A000000166492                           수이스킨 어린새싹 클린 토너 더블 기획세트
# 32201  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
#
#        water  serum  cream  oil  balm
# 0          0      0      0    0     0
# ...

# %%
for c in category:
    product.loc[product['name'].str.contains(eval(c)), c] += 1

# %%
 product
# Out:
#                   id                                               name  \
# 0      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 200    A000000192752  [2023어워즈/4년연속] 라운드랩 1025 독도 토너 500ml 어워즈 한정기획(...
# 400    A000000155253  [2023어워즈] 아비브 어성초 카밍 토너 스킨부스터 더블 기획 (200ml+200ml)
# 600    A000000192545  브링그린 티트리시카  수딩 토너 500ml 어워즈 한정기획(+크림20ml+징크테카세...
# 800    A000000174370                              바이오더마 하이드라비오 토너 500ml
# ...              ...                                                ...
# 31201  A000000141900   [1+1 모공케어] 유세린 더머토클린 클래리파잉 토너 더블기획 (200ml+200ml)
# 31401  A000000163510                      비욘드 엔젤아쿠아 수분 진정 토너 500ml (비건)
# 31801  A000000137657                               라네즈옴므 액티브워터 스킨 180ml
# 32001  A000000166492                           수이스킨 어린새싹 클린 토너 더블 기획세트
# 32201  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
#
#        water  serum  cream  oil  balm
# 0          1      0      0    0     0
# ...

# %%
product.to_csv('product_category_count.csv', index=False)
