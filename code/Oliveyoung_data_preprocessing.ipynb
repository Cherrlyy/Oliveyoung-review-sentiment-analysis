# %%
import pandas as pd

# %%
import re
import pandas as pd
from ckonlpy.tag import Twitter
import numpy as np

# 국어 자연어 처리 패키지인 konlpy 중 오픈소스 토크나이저 Okt사용
twitter = Twitter()

twitter.add_dictionary(['흡수력', '끈적임', '트러블', '자극적', '내돈내산', '가성비', '사용감', '저자극', '민감성',
                        '화농성', '블랙헤드', '대용량', '리무버', '밀착력', '유튜버', '강추', '수분감', '데일리', '유분기',
                        '정착템', '바디로션', '클렌징오일', '피부결', '스킨팩', '제형', '속건조', '복합성', '지성', '건성',
                        '클렌징워터', '재구매의사', '재구매', '재구매 의사', '닦토', '흡토', '수부지', '화장솜'], 'Noun')
twitter.add_dictionary(['가라앉다', '보들보들하다'], 'Adjective')

f = open('../stop_words.txt')
stopwords = f.read().split()


def preprocess(text):
    tokens = []
    non_kor_chars = re.compile('[^ 가-힣]')
    word = non_kor_chars.sub('', text)
    token = [t for (t,pos) in twitter.pos(text, stem=True) if pos in ['Noun', 'Verb', 'Adjective'] and t not in stopwords and len(t) > 1]
    preprocessed = ' '.join(token)
    return preprocessed
# Out:
# C:\Users\Joy\anaconda3\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %% [markdown]
# ### advertisement 전처리

# %%
ad = pd.read_csv("../oliveyoung_advertisement.csv", encoding="utf-8")
ad
# Out:
#      Unnamed: 0                                               name  len_img  \
# 0             0  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...      9.0
# 1             1  [12/4 하루특가][2023어워즈] 아비브 어성초 카밍 토너 스킨부스터 더블 기획...      4.0
# 2             2            [한정기획] 라네즈 크림스킨 170ml 리필 기획 (+170ml 리필)     10.0
# 3             3  [2023어워즈] 라운드랩 1025 독도 토너 500ml 어워즈 한정기획(+크림50...     17.0
# 4             4  [백현팬싸응모]브링그린 티트리시카 수딩 토너 500ml 어워즈 한정기획(+크림20m...     11.0
# ..          ...                                                ...      ...
# 290         290                      더마펌 울트라 수딩 토너 R4 200ml (수분진정)      9.0
# 291         291            아비브 어성초 카밍 토너 스킨부스터 500ml+화장솜 30매 증정 기획      3.0
# 292         292                 헤이네이처 어성초 스킨 토너 모이스처라이저 150ml (촉촉)      6.0
# 293         293                               더말로지카 멀티-액티브 토너 50ml      2.0
# 294         294                  [박보검 PICK] 비오템 옴므 포스 수프림 토너 200ml      1.0
#
#                                                     ad
# ...

# %%
# 데이터프레임 정리
ad = ad[["name","len_img","ad"]]
ad["len_img"] = ad["len_img"].astype(int)
# 결측치 처리
# ad.isnull().sum() -> len_img만 96개 결측치
ad = ad.dropna()
# 기타 전처리
ad["ad"] = ad["ad"].apply(preprocess)
ad = ad.reset_index(drop=True)
# Out:
# C:\Users\Joy\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ad
# Out:
#                                                   name  len_img  \
# 0    [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...        9
# 1    [12/4 하루특가][2023어워즈] 아비브 어성초 카밍 토너 스킨부스터 더블 기획...        4
# 2              [한정기획] 라네즈 크림스킨 170ml 리필 기획 (+170ml 리필)       10
# 3    [2023어워즈] 라운드랩 1025 독도 토너 500ml 어워즈 한정기획(+크림50...       17
# 4    [백현팬싸응모]브링그린 티트리시카 수딩 토너 500ml 어워즈 한정기획(+크림20m...       11
# ..                                                 ...      ...
# 194                      더마펌 울트라 수딩 토너 R4 200ml (수분진정)        9
# 195            아비브 어성초 카밍 토너 스킨부스터 500ml+화장솜 30매 증정 기획        3
# 196                 헤이네이처 어성초 스킨 토너 모이스처라이저 150ml (촉촉)        6
# 197                               더말로지카 멀티-액티브 토너 50ml        2
# 198                  [박보검 PICK] 비오템 옴므 포스 수프림 토너 200ml        1
#
#                                                     ad
# 0    단독 어워즈 한정 기획 버워스 토너 부문 단독 어워즈 한정 기획 아누 어성초 수딩 ...
# 1    올리브영 어워즈 진정 케어 기준 아비 어성초 토너 스킨 토너 어성초 토너 더블 어워...
# ...

# %%
ad.to_csv('oliveyoung_advertisement_preprocessed.csv', index=False)

# %% [markdown]
# ### review 전처리

# %%
review = pd.read_csv("../review.csv", encoding="UTF-8")
review
# Out:
#                   id                                               name  \
# 0      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 1      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 2      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 3      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 4      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# ...              ...                                                ...
# 33595  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
# 33596  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
# 33597  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
# 33598  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
# 33599  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
#
#              date                                            content
# ...

# %%
# 결측치 처리
# review.isnull().sum() -> name:1000개, content:191개 결측치
review = review.dropna()
# 기타 전처리
review["content"] = review["content"].apply(preprocess)
review = review.reset_index(drop=True)

# %%
review
# Out:
#                   id                                               name  \
# 0      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 1      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 2      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 3      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# 4      A000000192697  [2023어워즈/3년연속] 아누아 어성초 77 수딩 토너 350ml 어워즈 한정 기...
# ...              ...                                                ...
# 32405  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
# 32406  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
# 32407  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
# 32408  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
# 32409  A000000139057                            아벤느 이드랑스 딥 모이스트로션 200ml
#
#              date                                            content
# ...

# %%
review.to_csv('oliveyoung_review_preprocessed.csv', index=False)
